# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from google.colab.patches import cv2_imshow

# %%
x = np.load('data/C2_W2/data/X.npy')
y = np.load('data/C2_W2/data/y.npy')
x_t = cv2.imread('data/C2_W2/data/1.png',0)
cv2_imshow(x_t)
# Out:
# <PIL.Image.Image image mode=L size=20x20 at 0x7FE1FFE670A0>

# %%
display(np.shape(x))
display(np.shape(y))
np.shape(x_t)
# Out:
# (5000, 400)
# (5000, 1)
# (1, 400)

# %%
model = Sequential(
    [
        tf.keras.Input(shape=(400,)),
        Dense(500,activation='relu'),
        Dense(250,activation='relu'),
        Dense(125,activation='relu'),
        Dense(12,activation='relu'),
        Dense(69,activation='relu'),
        Dense(96,activation='relu'),
        Dense(101,activation='relu'),
        Dense(1000,activation='relu'),
        Dense(10,activation='linear')
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 500)               200500
#
#  dense_1 (Dense)             (None, 250)               125250
#
#  dense_2 (Dense)             (None, 125)               31375
#
#  dense_3 (Dense)             (None, 12)                1512
#
#  dense_4 (Dense)             (None, 69)                897
#
#  dense_5 (Dense)             (None, 96)                6720
#
#  dense_6 (Dense)             (None, 101)               9797
#
#  dense_7 (Dense)             (None, 1000)              102000
#
#  dense_8 (Dense)             (None, 10)                10010
#
# =================================================================
# Total params: 488,061
# Trainable params: 488,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.losses import SparseCategoricalCrossentropy
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=SparseCategoricalCrossentropy(from_logits='true')
)

# %%
history = model.fit(x,y,epochs=100)
# Out:
# Epoch 1/100
# 157/157 [==============================] - 5s 15ms/step - loss: 0.8687
# Epoch 2/100
# 157/157 [==============================] - 2s 11ms/step - loss: 0.2923
# Epoch 3/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1916
# Epoch 4/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1411
# Epoch 5/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.1198
# Epoch 6/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0973
# Epoch 7/100
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0762
# Epoch 8/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0775
# Epoch 9/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0460
# Epoch 10/100
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0645
# Epoch 11/100
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0588
# Epoch 12/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0535
# Epoch 13/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0860
# Epoch 14/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0377
# Epoch 15/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0206
# Epoch 16/100
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0328
# Epoch 17/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0631
# Epoch 18/100
# 157/157 [==============================] - 3s 16ms/step - loss: 0.0331
# Epoch 19/100
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0526
# Epoch 20/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0387
# Epoch 21/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0315
# Epoch 22/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0379
# Epoch 23/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0181
# Epoch 24/100
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0079
# Epoch 25/100
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0018
# Epoch 26/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0472
# Epoch 27/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0319
# Epoch 28/100
# 157/157 [==============================] - 3s 19ms/step - loss: 0.0567
# Epoch 29/100
# 157/157 [==============================] - 3s 17ms/step - loss: 0.0256
# Epoch 30/100
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0225
# Epoch 31/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0164
# Epoch 32/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0215
# Epoch 33/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0230
# Epoch 34/100
# 157/157 [==============================] - 2s 16ms/step - loss: 0.0339
# Epoch 35/100
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0294
# Epoch 36/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0093
# Epoch 37/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0021
# Epoch 38/100
# 157/157 [==============================] - 2s 10ms/step - loss: 9.1515e-04
# Epoch 39/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0013
# Epoch 40/100
# 157/157 [==============================] - 2s 10ms/step - loss: 0.0011
# Epoch 41/100
# 157/157 [==============================] - 2s 13ms/step - loss: 5.2093e-04
# Epoch 42/100
# 157/157 [==============================] - 2s 15ms/step - loss: 7.5007e-04
# Epoch 43/100
# 157/157 [==============================] - 2s 16ms/step - loss: 8.0401e-04
# Epoch 44/100
# 157/157 [==============================] - 2s 12ms/step - loss: 4.0991e-04
# Epoch 45/100
# 157/157 [==============================] - 2s 10ms/step - loss: 2.9153e-04
# Epoch 46/100
# 157/157 [==============================] - 2s 12ms/step - loss: 2.0893e-04
# Epoch 47/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.5836e-04
# Epoch 48/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1533e-04
# Epoch 49/100
# 157/157 [==============================] - 2s 10ms/step - loss: 8.1211e-05
# Epoch 50/100
# 157/157 [==============================] - 2s 15ms/step - loss: 5.5808e-05
# Epoch 51/100
# 157/157 [==============================] - 2s 15ms/step - loss: 3.6517e-05
# Epoch 52/100
# 157/157 [==============================] - 2s 15ms/step - loss: 2.5506e-05
# Epoch 53/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.7685e-05
# Epoch 54/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.2661e-05
# Epoch 55/100
# 157/157 [==============================] - 2s 14ms/step - loss: 1.0540e-05
# Epoch 56/100
# 157/157 [==============================] - 2s 10ms/step - loss: 8.4099e-06
# Epoch 57/100
# 157/157 [==============================] - 2s 10ms/step - loss: 6.2667e-06
# Epoch 58/100
# 157/157 [==============================] - 2s 12ms/step - loss: 4.8392e-06
# Epoch 59/100
# 157/157 [==============================] - 2s 16ms/step - loss: 3.9166e-06
# Epoch 60/100
# 157/157 [==============================] - 2s 16ms/step - loss: 3.2045e-06
# Epoch 61/100
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6358e-06
# Epoch 62/100
# 157/157 [==============================] - 2s 10ms/step - loss: 2.1770e-06
# Epoch 63/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.8324e-06
# Epoch 64/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.6044e-06
# Epoch 65/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.4517e-06
# Epoch 66/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1980e-06
# Epoch 67/100
# 157/157 [==============================] - 2s 12ms/step - loss: 1.0147e-06
# Epoch 68/100
# 157/157 [==============================] - 2s 15ms/step - loss: 8.7750e-07
# Epoch 69/100
# 157/157 [==============================] - 2s 16ms/step - loss: 7.6371e-07
# Epoch 70/100
# 157/157 [==============================] - 2s 12ms/step - loss: 6.8018e-07
# Epoch 71/100
# 157/157 [==============================] - 2s 10ms/step - loss: 6.2611e-07
# Epoch 72/100
# 157/157 [==============================] - 2s 10ms/step - loss: 5.3473e-07
# Epoch 73/100
# 157/157 [==============================] - 2s 10ms/step - loss: 4.6441e-07
# Epoch 74/100
# 157/157 [==============================] - 2s 10ms/step - loss: 4.0534e-07
# Epoch 75/100
# 157/157 [==============================] - 2s 10ms/step - loss: 3.6888e-07
# Epoch 76/100
# 157/157 [==============================] - 2s 12ms/step - loss: 3.1369e-07
# Epoch 77/100
# 157/157 [==============================] - 2s 15ms/step - loss: 2.6278e-07
# Epoch 78/100
# 157/157 [==============================] - 2s 16ms/step - loss: 2.2842e-07
# Epoch 79/100
# 157/157 [==============================] - 2s 12ms/step - loss: 2.0323e-07
# Epoch 80/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.8492e-07
# Epoch 81/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.6440e-07
# Epoch 82/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.4006e-07
# Epoch 83/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.2778e-07
# Epoch 84/100
# 157/157 [==============================] - 2s 10ms/step - loss: 1.1410e-07
# Epoch 85/100
# 157/157 [==============================] - 2s 12ms/step - loss: 1.0066e-07
# Epoch 86/100
# 157/157 [==============================] - 2s 16ms/step - loss: 8.9403e-08
# Epoch 87/100
# 157/157 [==============================] - 2s 15ms/step - loss: 8.1083e-08
# Epoch 88/100
# 157/157 [==============================] - 2s 12ms/step - loss: 7.3430e-08
# Epoch 89/100
# 157/157 [==============================] - 2s 11ms/step - loss: 6.4753e-08
# Epoch 90/100
# 157/157 [==============================] - 2s 10ms/step - loss: 5.9460e-08
# Epoch 91/100
# 157/157 [==============================] - 2s 10ms/step - loss: 5.9245e-08
# Epoch 92/100
# 157/157 [==============================] - 2s 10ms/step - loss: 5.1855e-08
# Epoch 93/100
# 157/157 [==============================] - 2s 10ms/step - loss: 4.5466e-08
# Epoch 94/100
# 157/157 [==============================] - 2s 12ms/step - loss: 4.1484e-08
# Epoch 95/100
# 157/157 [==============================] - 2s 15ms/step - loss: 3.7264e-08
# Epoch 96/100
# 157/157 [==============================] - 2s 16ms/step - loss: 3.4284e-08
# Epoch 97/100
# 157/157 [==============================] - 2s 12ms/step - loss: 3.0732e-08
# Epoch 98/100
# 157/157 [==============================] - 2s 10ms/step - loss: 2.8348e-08
# Epoch 99/100
# 157/157 [==============================] - 2s 10ms/step - loss: 2.7203e-08
# Epoch 100/100
# 157/157 [==============================] - 2s 10ms/step - loss: 2.4009e-08

# %%
prediction = model.predict(x_t.reshape(1,400))
display(prediction)
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array([[-6435.1025, -2936.589 , -3299.6375, -4508.157 ,  6713.929 ,
#         -3096.894 , -4612.968 , -2907.304 , -6640.605 , -4021.117 ]],
#       dtype=float32)
# 4
